# %% [markdown]
# <a href="https://colab.research.google.com/github/Akshiiiita/Machine-Learning/blob/main/Pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# Creating a pandas dataframe

# %%
# importing the diabetes house price data
from sklearn.datasets import load_diabetes

# %%
diabetes_dataset = load_diabetes()

# %%
type(diabetes_dataset)
# Out:
# sklearn.utils._bunch.Bunch

# %%
print(diabetes_dataset)
# Out:
# {'data': array([[ 0.03807591,  0.05068012,  0.06169621, ..., -0.00259226,
#          0.01990749, -0.01764613],
#        [-0.00188202, -0.04464164, -0.05147406, ..., -0.03949338,
#         -0.06833155, -0.09220405],
#        [ 0.08529891,  0.05068012,  0.04445121, ..., -0.00259226,
#          0.00286131, -0.02593034],
#        ...,
#        [ 0.04170844,  0.05068012, -0.01590626, ..., -0.01107952,
#         -0.04688253,  0.01549073],
#        [-0.04547248, -0.04464164,  0.03906215, ...,  0.02655962,
#          0.04452873, -0.02593034],
#        [-0.04547248, -0.04464164, -0.0730303 , ..., -0.03949338,
#         -0.00422151,  0.00306441]]), 'target': array([151.,  75., 141., 206., 135.,  97., 138.,  63., 110., 310., 101.,
#         69., 179., 185., 118., 171., 166., 144.,  97., 168.,  68.,  49.,
#         68., 245., 184., 202., 137.,  85., 131., 283., 129.,  59., 341.,
#         87.,  65., 102., 265., 276., 252.,  90., 100.,  55.,  61.,  92.,
# ...

# %%
# pandas dataframe
diabetes_df1 = pd.DataFrame(diabetes_dataset.data, columns = diabetes_dataset.feature_names)

# %%
diabetes_df1.head()
# Out:
#         age       sex       bmi        bp        s1        s2        s3  \
# 0  0.038076  0.050680  0.061696  0.021872 -0.044223 -0.034821 -0.043401
# 1 -0.001882 -0.044642 -0.051474 -0.026328 -0.008449 -0.019163  0.074412
# 2  0.085299  0.050680  0.044451 -0.005670 -0.045599 -0.034194 -0.032356
# 3 -0.089063 -0.044642 -0.011595 -0.036656  0.012191  0.024991 -0.036038
# 4  0.005383 -0.044642 -0.036385  0.021872  0.003935  0.015596  0.008142
#
#          s4        s5        s6
# 0 -0.002592  0.019907 -0.017646
# 1 -0.039493 -0.068332 -0.092204
# 2 -0.002592  0.002861 -0.025930
# 3  0.034309  0.022688 -0.009362
# 4 -0.002592 -0.031988 -0.046641

# %%
diabetes_df1.shape
# Out:
# (442, 10)

# %% [markdown]
# Imporing he data from a csv file to a pandas dataframe

# %%
# csv file to pandas df
diaabetes_df = pd.read_csv('/content/drive/MyDrive/pima-indians-diabetes.csv')

# %%
type(diaabetes_df)
# Out:
# pandas.core.frame.DataFrame

# %%
diaabetes_df.head()
# Out:
#    6  148  72  35    0  33.6  0.627  50  1
# 0  1   85  66  29    0  26.6  0.351  31  0
# 1  8  183  64   0    0  23.3  0.672  32  1
# 2  1   89  66  23   94  28.1  0.167  21  0
# 3  0  137  40  35  168  43.1  2.288  33  1
# 4  5  116  74   0    0  25.6  0.201  30  0

# %%
diaabetes_df.shape
# Out:
# (767, 9)

# %% [markdown]
# loading the data from a excel file to a pandas dataframe

# %%
# pd.read_excel('file path')
diabetes_df1.to_csv('diabetes.csv')

# %% [markdown]
# exporting the pandas dataframe to an excel file

# %%
# df.to_excel('file name')
# creating a dataframe with random value
random_df = pd.DataFrame(np.random.rand(20,10))

# %%
random_df.head()
# Out:
#           0         1         2         3         4         5         6  \
# 0  0.283428  0.084281  0.219451  0.148337  0.002709  0.301516  0.163173
# 1  0.459497  0.005028  0.441195  0.141548  0.702725  0.964533  0.510596
# 2  0.544084  0.629004  0.451524  0.065129  0.699868  0.084654  0.159350
# 3  0.867084  0.008984  0.922069  0.183852  0.758389  0.481119  0.635010
# 4  0.410882  0.167268  0.388868  0.025952  0.737568  0.708843  0.513756
#
#           7         8         9
# 0  0.521990  0.642468  0.003114
# 1  0.456636  0.783886  0.669729
# 2  0.072398  0.411424  0.173633
# 3  0.936308  0.628061  0.074293
# 4  0.968017  0.604909  0.808483

# %%
random_df.shape
# Out:
# (20, 10)

# %% [markdown]
# Inspecting a dataframe

# %%
# finding the number df rows and columns
diabetes_df1.shape
# Out:
# (442, 10)

# %%
# first 5 rows in a dataframe
diabetes_df1.head()
# Out:
#         age       sex       bmi        bp        s1        s2        s3  \
# 0  0.038076  0.050680  0.061696  0.021872 -0.044223 -0.034821 -0.043401
# 1 -0.001882 -0.044642 -0.051474 -0.026328 -0.008449 -0.019163  0.074412
# 2  0.085299  0.050680  0.044451 -0.005670 -0.045599 -0.034194 -0.032356
# 3 -0.089063 -0.044642 -0.011595 -0.036656  0.012191  0.024991 -0.036038
# 4  0.005383 -0.044642 -0.036385  0.021872  0.003935  0.015596  0.008142
#
#          s4        s5        s6
# 0 -0.002592  0.019907 -0.017646
# 1 -0.039493 -0.068332 -0.092204
# 2 -0.002592  0.002861 -0.025930
# 3  0.034309  0.022688 -0.009362
# 4 -0.002592 -0.031988 -0.046641

# %%
# last 5 rows of the dataframe
diabetes_df1.tail()
# Out:
#           age       sex       bmi        bp        s1        s2        s3  \
# 437  0.041708  0.050680  0.019662  0.059744 -0.005697 -0.002566 -0.028674
# 438 -0.005515  0.050680 -0.015906 -0.067642  0.049341  0.079165 -0.028674
# 439  0.041708  0.050680 -0.015906  0.017293 -0.037344 -0.013840 -0.024993
# 440 -0.045472 -0.044642  0.039062  0.001215  0.016318  0.015283 -0.028674
# 441 -0.045472 -0.044642 -0.073030 -0.081413  0.083740  0.027809  0.173816
#
#            s4        s5        s6
# 437 -0.002592  0.031193  0.007207
# 438  0.034309 -0.018114  0.044485
# 439 -0.011080 -0.046883  0.015491
# 440  0.026560  0.044529 -0.025930
# 441 -0.039493 -0.004222  0.003064

# %%
# information about the dataframe
diabetes_df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 442 entries, 0 to 441
# Data columns (total 10 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   age     442 non-null    float64
#  1   sex     442 non-null    float64
#  2   bmi     442 non-null    float64
#  3   bp      442 non-null    float64
#  4   s1      442 non-null    float64
#  5   s2      442 non-null    float64
#  6   s3      442 non-null    float64
#  7   s4      442 non-null    float64
#  8   s5      442 non-null    float64
#  9   s6      442 non-null    float64
# dtypes: float64(10)
# memory usage: 34.7 KB

# %%
# finding the no. of missing values
diabetes_df1.isnull().sum()
# Out:
# age    0
# sex    0
# bmi    0
# bp     0
# s1     0
# s2     0
# s3     0
# s4     0
# s5     0
# s6     0
# dtype: int64

# %%
# diabetes dataframe
diaabetes_df.head()
# Out:
#    6  148  72  35    0  33.6  0.627  50  1
# 0  1   85  66  29    0  26.6  0.351  31  0
# 1  8  183  64   0    0  23.3  0.672  32  1
# 2  1   89  66  23   94  28.1  0.167  21  0
# 3  0  137  40  35  168  43.1  2.288  33  1
# 4  5  116  74   0    0  25.6  0.201  30  0

# %%
# counting the values based on the labels
diaabetes_df.value_counts('1')
# Out:
# 1
# 0    500
# 1    267
# dtype: int64

# %%
# group the values based on the mean
diaabetes_df.groupby('1').mean()
# Out:
#           6        148         72         35          0       33.6     0.627  \
# 1
# 0  3.298000  109.98000  68.184000  19.664000   68.79200  30.304200  0.429734
# 1  4.861423  141.23221  70.820225  22.116105  100.71161  35.148315  0.550213
#
#           50
# 1
# 0  31.190000
# 1  37.018727

# %% [markdown]
# Statistical measures

# %%
# count or no. of values
diabetes_df1.count()
# Out:
# age    442
# sex    442
# bmi    442
# bp     442
# s1     442
# s2     442
# s3     442
# s4     442
# s5     442
# s6     442
# dtype: int64

# %%
# mean value-column wise
diabetes_df1.mean()
# Out:
# age   -1.444295e-18
# sex    2.543215e-18
# bmi   -2.255925e-16
# bp    -4.854086e-17
# s1    -1.428596e-17
# s2     3.898811e-17
# s3    -6.028360e-18
# s4    -1.788100e-17
# s5     9.243486e-17
# s6     1.351770e-17
# dtype: float64

# %%
# standard deviation-column wise
diabetes_df1.std()
# Out:
# age    0.047619
# sex    0.047619
# bmi    0.047619
# bp     0.047619
# s1     0.047619
# s2     0.047619
# s3     0.047619
# s4     0.047619
# s5     0.047619
# s6     0.047619
# dtype: float64

# %%
# minimum value in each column
diabetes_df1.min()
# Out:
# age   -0.107226
# sex   -0.044642
# bmi   -0.090275
# bp    -0.112399
# s1    -0.126781
# s2    -0.115613
# s3    -0.102307
# s4    -0.076395
# s5    -0.126097
# s6    -0.137767
# dtype: float64

# %%
# maximum value in each column
diabetes_df1.max()
# Out:
# age    0.110727
# sex    0.050680
# bmi    0.170555
# bp     0.132044
# s1     0.153914
# s2     0.198788
# s3     0.181179
# s4     0.185234
# s5     0.133597
# s6     0.135612
# dtype: float64

# %%
# all the statistical measures about the dataframe
diabetes_df1.describe()
# Out:
#                 age           sex           bmi            bp            s1  \
# count  4.420000e+02  4.420000e+02  4.420000e+02  4.420000e+02  4.420000e+02
# mean  -2.511817e-19  1.230790e-17 -2.245564e-16 -4.797570e-17 -1.381499e-17
# std    4.761905e-02  4.761905e-02  4.761905e-02  4.761905e-02  4.761905e-02
# min   -1.072256e-01 -4.464164e-02 -9.027530e-02 -1.123988e-01 -1.267807e-01
# 25%   -3.729927e-02 -4.464164e-02 -3.422907e-02 -3.665608e-02 -3.424784e-02
# 50%    5.383060e-03 -4.464164e-02 -7.283766e-03 -5.670422e-03 -4.320866e-03
# 75%    3.807591e-02  5.068012e-02  3.124802e-02  3.564379e-02  2.835801e-02
# max    1.107267e-01  5.068012e-02  1.705552e-01  1.320436e-01  1.539137e-01
#
#                  s2            s3            s4            s5            s6
# count  4.420000e+02  4.420000e+02  4.420000e+02  4.420000e+02  4.420000e+02
# mean   3.918434e-17 -5.777179e-18 -9.042540e-18  9.293722e-17  1.130318e-17
# ...

# %% [markdown]
# manipulating a dataframe

# %%
# adding a column to a dataframe
diabetes_df1['Prices'] = diabetes_dataset.target

# %%
diabetes_df1.head()
# Out:
#         age       sex       bmi        bp        s1        s2        s3  \
# 0  0.038076  0.050680  0.061696  0.021872 -0.044223 -0.034821 -0.043401
# 1 -0.001882 -0.044642 -0.051474 -0.026328 -0.008449 -0.019163  0.074412
# 2  0.085299  0.050680  0.044451 -0.005670 -0.045599 -0.034194 -0.032356
# 3 -0.089063 -0.044642 -0.011595 -0.036656  0.012191  0.024991 -0.036038
# 4  0.005383 -0.044642 -0.036385  0.021872  0.003935  0.015596  0.008142
#
#          s4        s5        s6  Prices
# 0 -0.002592  0.019907 -0.017646   151.0
# 1 -0.039493 -0.068332 -0.092204    75.0
# 2 -0.002592  0.002861 -0.025930   141.0
# 3  0.034309  0.022688 -0.009362   206.0
# 4 -0.002592 -0.031988 -0.046641   135.0

# %%
# removing a prticular column
diabetes_df1.drop(index=0, axis=0)
# Out:
#           age       sex       bmi        bp        s1        s2        s3  \
# 1   -0.001882 -0.044642 -0.051474 -0.026328 -0.008449 -0.019163  0.074412
# 2    0.085299  0.050680  0.044451 -0.005670 -0.045599 -0.034194 -0.032356
# 3   -0.089063 -0.044642 -0.011595 -0.036656  0.012191  0.024991 -0.036038
# 4    0.005383 -0.044642 -0.036385  0.021872  0.003935  0.015596  0.008142
# 5   -0.092695 -0.044642 -0.040696 -0.019442 -0.068991 -0.079288  0.041277
# ..        ...       ...       ...       ...       ...       ...       ...
# 437  0.041708  0.050680  0.019662  0.059744 -0.005697 -0.002566 -0.028674
# 438 -0.005515  0.050680 -0.015906 -0.067642  0.049341  0.079165 -0.028674
# 439  0.041708  0.050680 -0.015906  0.017293 -0.037344 -0.013840 -0.024993
# 440 -0.045472 -0.044642  0.039062  0.001215  0.016318  0.015283 -0.028674
# 441 -0.045472 -0.044642 -0.073030 -0.081413  0.083740  0.027809  0.173816
#
#            s4        s5        s6  Prices
# ...

# %%
# drop a column
diabetes_df1.drop(columns='sex', axis=1)
# Out:
#           age       bmi        bp        s1        s2        s3        s4  \
# 0    0.038076  0.061696  0.021872 -0.044223 -0.034821 -0.043401 -0.002592
# 1   -0.001882 -0.051474 -0.026328 -0.008449 -0.019163  0.074412 -0.039493
# 2    0.085299  0.044451 -0.005670 -0.045599 -0.034194 -0.032356 -0.002592
# 3   -0.089063 -0.011595 -0.036656  0.012191  0.024991 -0.036038  0.034309
# 4    0.005383 -0.036385  0.021872  0.003935  0.015596  0.008142 -0.002592
# ..        ...       ...       ...       ...       ...       ...       ...
# 437  0.041708  0.019662  0.059744 -0.005697 -0.002566 -0.028674 -0.002592
# 438 -0.005515 -0.015906 -0.067642  0.049341  0.079165 -0.028674  0.034309
# 439  0.041708 -0.015906  0.017293 -0.037344 -0.013840 -0.024993 -0.011080
# 440 -0.045472  0.039062  0.001215  0.016318  0.015283 -0.028674  0.026560
# 441 -0.045472 -0.073030 -0.081413  0.083740  0.027809  0.173816 -0.039493
#
#            s5        s6  Prices
# 0    0.019907 -0.017646   151.0
# ...

# %%
# locating a row using index value
diabetes_df1.iloc[2]
# Out:
# age         0.085299
# sex         0.050680
# bmi         0.044451
# bp         -0.005670
# s1         -0.045599
# s2         -0.034194
# s3         -0.032356
# s4         -0.002592
# s5          0.002861
# s6         -0.025930
# Prices    141.000000
# Name: 2, dtype: float64

# %%
# locating a column
print(diabetes_df1.iloc[:,0]) #first column
print(diabetes_df1.iloc[:,1]) #second column
# Out:
# 0      0.038076
# 1     -0.001882
# 2      0.085299
# 3     -0.089063
# 4      0.005383
#          ...
# 437    0.041708
# 438   -0.005515
# 439    0.041708
# 440   -0.045472
# 441   -0.045472
# Name: age, Length: 442, dtype: float64
# 0      0.050680
# 1     -0.044642
# 2      0.050680
# 3     -0.044642
# 4     -0.044642
#          ...
# 437    0.050680
# 438    0.050680
# 439    0.050680
# 440   -0.044642
# 441   -0.044642
# Name: sex, Length: 442, dtype: float64

# %% [markdown]
# Correlation
#
# 1.  Positive correlation
# 2.  Negative correlation

# %%
diabetes_df1.corr()
# Out:
#              age       sex       bmi        bp        s1        s2        s3  \
# age     1.000000  0.173737  0.185085  0.335428  0.260061  0.219243 -0.075181
# sex     0.173737  1.000000  0.088161  0.241010  0.035277  0.142637 -0.379090
# bmi     0.185085  0.088161  1.000000  0.395411  0.249777  0.261170 -0.366811
# bp      0.335428  0.241010  0.395411  1.000000  0.242464  0.185548 -0.178762
# s1      0.260061  0.035277  0.249777  0.242464  1.000000  0.896663  0.051519
# s2      0.219243  0.142637  0.261170  0.185548  0.896663  1.000000 -0.196455
# s3     -0.075181 -0.379090 -0.366811 -0.178762  0.051519 -0.196455  1.000000
# s4      0.203841  0.332115  0.413807  0.257650  0.542207  0.659817 -0.738493
# s5      0.270774  0.149916  0.446157  0.393480  0.515503  0.318357 -0.398577
# s6      0.301731  0.208133  0.388680  0.390430  0.325717  0.290600 -0.273697
# Prices  0.187889  0.043062  0.586450  0.441482  0.212022  0.174054 -0.394789
#
# ...
